# %%
a = [1, 2, 3]
a.append([4, 5])
print(a)
print(len(a))
# Out:
# [1, 2, 3, [4, 5]]
# 4

# %%
a = [1, 2, 3]
print(a * 2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a = [1, 2, 3, 4]
print(a[-2:0:-1])
# Out:
# [3, 2]

# %%
a = [1, 2, 3]
a.insert(0, a)
print(a)
print(a[0])
print(a[0][0])
# Out:
# [[...], 1, 2, 3]
# [[...], 1, 2, 3]
# [[...], 1, 2, 3]

# %%
x = [1, 2, 3]
y = x
y.append(4)
print(x)
# Out:
# [1, 2, 3, 4]

# %%
t = (1)
print(type(t))
# Out:
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 t = (1)
#       2 print(type(t))
# ----> 3 help(d.get())
#
# TypeError: get expected at least 1 argument, got 0

# %%
t = (1, 2, 3)
print(t[1:2])
# Out:
# (2,)

# %%
t = (1, 2, [3, 4])
t[2][0] = 99
print(t)
# Out:
# (1, 2, [99, 4])

# %%
d = {"a": 1, "b": 2}
print(d.get("z",100))
print(d)
# Out:
# 100
# {'a': 1, 'b': 2}

# %%
d = {}
print(d.setdefault("x", 5))
print(d)
# Out:
# 5
# {'x': 5}

# %%
d = {"a": 1, "b": 2}
print(d.setdefault("a", 100))
print(d)
# Out:
# 1
# {'a': 1, 'b': 2}

# %%
d = {"x": 10, "y": 20}
print(list(d.keys())[0])
# Out:
# x

# %%
d = {"a": 1, "b": 2}
print(d.get("c"))
# Out:
# None

# %%
d = {}
print(d.setdefault("a"))
print(d)
# Out:
# None
# {'a': None}

# %%
d = {"x": 1}
d2 = d
d2["y"] = 2
print(d)
# Out:
# {'x': 1, 'y': 2}

# %%
s = {1, 2, 3, 2, 1}
print(len(s))
# Out:
# 3

# %%
s = {1, 2, 3}
s.add(2)
print(s)
# Out:
# {1, 2, 3}

# %%
s = {1, 2, 3}
print(s.pop())
# Out:
# 1

# %%
s1 = {1, 2}
s2 = {2, 3}
print(s1 & s2)
# Out:
# {2}

# %%
s1 = {1, 2}
s2 = {2, 3}
print(s1 | s2)
# Out:
# {1, 2, 3}

# %%
s = set("banana")
print(s)
# Out:
# {'a', 'n', 'b'}

# %%
s = {1, 2, 3}
print(s.discard(5))
print(s)
# Out:
# None
# {1, 2, 3}

# %%
x = [1, 2, 3]
print(x == x[:])
# Out:
# True

# %%
x = [1, 2, 3]
print(x is x[:])
# Out:
# False

# %%
d = {"a": 1}
print("a" in d)
# Out:
# True

# %%
print([] is [])
# Out:
# False

# %%
print((1, 2) * 2)
# Out:
# (1, 2, 1, 2)

# %%
d = {"a": 1, "b": 2}
print(d.items())
# Out:
# dict_items([('a', 1), ('b', 2)])

# %%
d = {"a": 1}
print(d.get("a") + d.get("b", 5))
# Out:
# 6

# %%
a = [1, 2, 3]
b = a
a = a + [4]
print(b)
# Out:
# [1, 2, 3]

# %%
x = {}
print(x.setdefault("a"))
print(x)
# Out:
# None
# {'a': None}

# %%
x = {}
print(x.setdefault("a"))
print(x)
# Out:
# None
# {'a': None}

# %%
x = {0: "zero", False: "false"}
print(x)
# Out:
# {0: 'false'}

# %%
x = {True: "yes", 1: "no"}
print(x)
# Out:
# {True: 'no'}

# %%
a = [1, 2, 3]
b = a
a += [4]  # a+=[4] is a shorthand for the extend , so it adds value to the existing list
print(b)
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 3]
b = a
a = a + [4] # It is kind of reassignment , so it creates a new list.
print(b)
# Out:
# [1, 2, 3]

# %%
d = {"a": 1}
print(d.get("a") + d.get("b", 5))
# Out:
# 6

# %%
d = {"a": 1, "b": 2}
print(d.items())
# Out:
# dict_items([('a', 1), ('b', 2)])

# %%
print((1, 2) * 2)
# Out:
# (1, 2, 1, 2)

# %%
print([] is [])
# Out:
# False

# %%
s = {1, 2, 3}
print(s.discard(5))
print(s)
# Out:
# None
# {1, 2, 3}

# %%
f = lambda x: x**2
print(f(5))
# Out:
# 25

# %%
f = lambda x, y=2: x * y
print(f(3))
# Out:
# 6

# %%
f = lambda x, y: x if x > y else y
print(f(2, 5))
# Out:
# 5

# %%
nums = [i*i for i in range(4)]
print(nums)
# Out:
# [0, 1, 4, 9]

# %%
nums = [i for i in range(5) if i % 2 == 0]
print(nums)
# Out:
# [0, 2, 4]

# %%
a = [[i for i in range(3)] for j in range(2)]
print(a)
# Out:
# [[0, 1, 2], [0, 1, 2]]

# %%
nums = [1, 2, 3]
res = map(lambda x: x*2, nums)
print(list(res))
# Out:
# [2, 4, 6]

# %%
nums = [1, 2, 3]
res = map(str, nums)
# print(map(str,nums))
print("".join(res))
# Out:
# ...
# 123

# %%
a = [1, 2]
b = [3, 4, 5]
print(list(map(lambda x, y: x+y, a, b)))
# Out:
# [4, 6]

# %%
nums = [1, 2, 3, 4]
res = filter(lambda x: x % 2==0, nums)
print(list(res))
# Out:
# [2, 4]

# %%
s = "python"
res = filter(str.islower, s)
print("".join(res))
# Out:
# python

# %%
from functools import reduce
nums = [1, 2, 3, 4]
print(reduce(lambda x, y: x + y, nums))
# Out:
# 10

# %%
from functools import reduce
nums = [1, 2, 3, 4]
print(reduce(lambda x, y: x * y, nums, 2))
# Out:
# 48

# %%
a = [1, 2, 3]
print(a.pop())
# Out:
# 3

# %%
a = [1, 2, 3]
print(a.pop(0))
# Out:
# 1

# %%
a = [1, 2, 3]
a.remove(2)
print(a)
# Out:
# [1, 3]

# %%
d = {"a": 1, "b": 2}
print(d.keys())
print(d.pop("a"))
print(d)
# Out:
# dict_keys(['a', 'b'])
# 1
# {'b': 2}

# %%
d = {"x": 10, "y": 20}
print(d.popitem())
print(d)
# Out:
# ('y', 20)
# {'x': 10}

# %%
d = {"a": 1}
print(d.setdefault("b", 100))
print(d)
# Out:
# 100
# {'a': 1, 'b': 100}

# %%
d = {"a": 1}
print(d.setdefault("a", 99))
# Out:
# 1

# %%
x = 5
def f():
    x = 10
    print(x)
f()
# Out:
# 10

# %%
x = 5
def f():
    print(x)
f()
# Out:
# 5

# %%
x = 5
def f():
    global x
    x = 10
f()
print(x)
# Out:
# 10

# %%
def outer():
    x = 5
    def inner():
        nonlocal x
        x += 1
        return x
    return inner()
print(outer())
# Out:
# 6

# %%
print([i for i in "hello" if i not in "aeiou"])
# Out:
# ['h', 'l', 'l']

# %%
print([i*2 for i in [1, 2, 3]])
# Out:
# [2, 4, 6]

# %%
print({i: i*i for i in range(3)})
# Out:
# {0: 0, 1: 1, 2: 4}

# %%
a = [1, 2, 3]
b = [i for i in a if i > 1]
print(b)
# Out:
# [2, 3]

# %%
a = [1, 2, 3]
b = [i for i in a if i > 1]
print(b)
# Out:
# [2, 3]

# %%
nums = [1, 2, 3]
print(list(map(lambda x: x**2, filter(lambda y: y > 1, nums))))
# Out:
# [4, 9]

# %%
words = ["hi", "hello", "python"]
print(list(map(len, words)))
# Out:
# [2, 5, 6]

# %%
nums = [0, 1, 2, 3]
print(all(nums)) # all returns if all elements are truthy , otherwise false
# Out:
# False

# %%
nums = [0, 1, 2, 3]
print(any(nums))
# Out:
# True

# %%
print(max([], default="empty"))  # max accepts an iterable and return the max value from it and if the default value is passed then it return the default value passed to the default keyword
# Out:
# empty

# %%
nums = [1, 2, 3]
print(sum(nums, 10))
# Out:
# 16

# %%
a = ["1", "2", "3"]
print(list(map(int, a)))
# Out:
# [1, 2, 3]
